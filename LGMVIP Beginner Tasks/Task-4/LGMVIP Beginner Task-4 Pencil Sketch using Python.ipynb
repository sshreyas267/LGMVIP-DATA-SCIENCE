# %% [markdown]
# # LGMVIP-January
#
# ## Beginner Task-4: Pencil Sketch using Python
#
# ### Shreyas S

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image

# %%
#Importing required libraries
import cv2
import matplotlib.pyplot as plt

# %%
#Reading image
img=cv2.imread("lion.jpg")

img1=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Displaying Original Image

# %%
plt.imshow(img1)

# %% [markdown]
# ### Converting the image to grayscale

# %%
gray_img=cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

gray_img1=cv2.cvtColor(gray_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(gray_img1)

# %% [markdown]
# ### Inverting the Image

# %%
inv_img=255-gray_img1

inv_img1=cv2.cvtColor(inv_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(inv_img1)

# %% [markdown]
# ### Blurring the Image

# %%
blurred_img=cv2.GaussianBlur(inverted_image, (21, 21), 0)

blurred_img1=cv2.cvtColor(blurred_img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(blurred_img1)

# %% [markdown]
# ### Inverting Blurred Image

# %%
inverted_blurred=255-blurred_img1

pencil_sketch=cv2.divide(gray_img1, inverted_blurred, scale=260.0)

final_sketch=cv2.cvtColor(pencil_sketch, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Final Pencil Sketch Image

# %%
plt.imshow(final_sketch)
